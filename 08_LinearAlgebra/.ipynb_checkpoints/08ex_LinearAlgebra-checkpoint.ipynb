# %%
import pandas as pd
import numpy as np
import numpy.random as npr
from scipy import linalg as la
from matplotlib import pyplot as plt

# %% [markdown]
# 1\. **PCA on 3D dataset**
#
# * Generate a dataset with 3 features each with N entries (N being ${\cal O}(1000)$). With $N(\mu,\sigma)$ the normali distribution with mean $\mu$ and $\sigma$  standard deviation, generate the 3 variables $x_{1,2,3}$ such that:
#     * $x_1$ is distributed as $N(0,1)$
#     * $x_2$ is distributed as $x_1+N(0,3)$
#     * $x_3$ is given by $2x_1+x_2$
# * Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
# * Find the eigenvectors and eigenvalues using SVD. Check that the two procedures yield to same result
# * What percent of the total dataset's variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained.
# * Redefine the data in the basis yielded by the PCA procedure
# * Plot the data points in the original and the new coordiantes as a set of scatter plots. Your final figure should have 2 rows of 3 plots each, where the columns show the (0,1), (0,2) and (1,2) proejctions.

# %%
n = 1000
sigma = 3

# Dataset
x_1 = npr.normal(0, 1, n)
x_2 = x_1 + npr.normal(0, 3, n) * sigma
x_3 = 2 * x_1 + x_2
dataset = np.array([x_1, x_2, x_3]).T

cov = np.cov(dataset, rowvar=False)
l, V = la.eigh(cov) 

U, spectrum, Vt = la.svd(dataset)
l_svd = spectrum**2 / (n - 1)

print (cov)
print (l)
print (l_svd, '\n')

D = np.diag(l)
D_trace = D.trace()
cov_trace = cov.trace()

print ("Percent of each component:")
for i in l:
    print (i.real / cov_trace )

V_PCA = V[:,1:]
Xp = np.dot(dataset,V_PCA)
# Out:
# [[ 1.0298682   0.89272636  2.95246275]
#  [ 0.89272636 82.98010709 84.7655598 ]
#  [ 2.95246275 84.7655598  90.6704853 ]]
# [3.28368629e-15 2.95808675e+00 1.71722374e+02]
# [1.71745661e+02 2.96129716e+00 9.92407387e-31]
#
# Percent of each component:
# 1.8798246120777043e-17
# 0.01693427379583216
# 0.9830657262041667

# %%
sf = 0.2 # scale factor
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12, 7))

# OLD COORDINATES
# (0,1) projection
axes[0, 0].scatter(dataset[:,0], dataset[:,1], marker='.', color='red', alpha=0.5, label="(0,1)")
axes[0, 0].plot([0, sf*l[0]*V[0,0]], [0, sf*l[0]*V[1,0]], color='blue', lw=2)
axes[0, 0].plot([0, sf*l[1]*V[0,1]], [0, sf*l[1]*V[1,1]], color='blue', lw=2)

# (0,2) projection
axes[0, 1].scatter(dataset[:,0], dataset[:,2], marker='.', color='red', alpha=0.5, label="(0,2)")
axes[0, 1].plot([0, sf*l[0]*V[0, 0]], [0, sf*l[0] * V[2, 0]], color='blue', lw=2)
axes[0, 1].plot([0, sf*l[2]*V[0, 2]], [0, sf*l[2] * V[2, 2]], color='blue', lw=2)

# (1,2) projection 
axes[0, 2].scatter(dataset[:,1], dataset[:,2], marker='.', color='red', alpha=0.5, label="(1,2)")
axes[0, 2].plot([0, sf*l[1]*V[1, 1]], [0, sf*l[1].real * V[2, 1]], color='blue', lw=2)
axes[0, 2].plot([0, sf*l[2]*V[1, 2]], [0, sf*l[2].real * V[2, 2]], color='blue', lw=2)


# NEW COORDINATES
# (0,1) projection
axes[1, 0].scatter(Xp[:,0], Xp[:,1], marker='.', color='red', alpha=0.5, label="(0,1)")
axes[1, 0].plot([0, sf*l[0]*V[0,0]], [0, sf*l[0]*V[1,0]], color='blue', lw=2)
axes[1, 0].plot([0, sf*l[1]*V[0,1]], [0, sf*l[1]*V[1,1]], color='blue', lw=2)

# (0,2) projection
axes[1, 1].scatter(Xp[:,0], Xp[:,2], marker='.', color='red', alpha=0.5, label="(0,2)")
axes[1, 1].plot([0, sf*l[0]*V[0, 0]], [0, sf*l[0] * V[2, 0]], color='blue', lw=2)
axes[1, 1].plot([0, sf*l[2]*V[0, 2]], [0, sf*l[2] * V[2, 2]], color='blue', lw=2)

# (1,2) projection 
axes[1, 2].scatter(Xp[:,1], Xp[:,2], marker='.', color='red', alpha=0.5, label="(1,2)")
axes[1, 2].plot([0, sf*l[1]*V[1, 1]], [0, sf*l[1].real * V[2, 1]], color='blue', lw=2)
axes[1, 2].plot([0, sf*l[2]*V[1, 2]], [0, sf*l[2].real * V[2, 2]], color='blue', lw=2)



axes[0, 1].set_title("Original coordinates", fontsize=14, loc='center')
axes[1, 1].set_title("New coordinates", fontsize=14, loc='center')

for row in axes:
    for ax in row:
        ax.legend()
        
plt.tight_layout()
plt.show()

# %% [markdown]
# 2\. **PCA on a nD dataset**
#
# Start from the dataset you have genereted in the previous exercise and add uncorrelated random noise. Such noise should be represented by other 10 uncorrelated variables normal distributed, with standar deviation much smaller (say, a factor 50) than those used to generate the $x_1$ and $x_2$.
#
# Repeat the PCA procedure and compare the results with what you obtained before

# %%
# Noise
Noise = np.zeros(n)
sigma_noise = 1 / 50

noise_variables = [npr.normal(0, sigma_noise, n) for _ in range(10)]
noise_matrix = np.array(noise_variables)
Noise = noise_matrix.sum(axis=0)

# Dataset with noise
x_1 = npr.normal(0, 1, n) + Noise
x_2 = x_1 + npr.normal(0, 3, n) * sigma + Noise
x_3 = 2 * x_1 + x_2 + Noise
dataset = np.array([x_1, x_2, x_3]).T

# %%
cov = np.cov(dataset, rowvar=False)
l, V = la.eigh(cov) 

U, spectrum, Vt = la.svd(dataset)
l_svd = spectrum**2 / (n - 1)

print (cov)
print (l)
print (l_svd, '\n')

D = np.diag(l)
D_trace = D.trace()
cov_trace = cov.trace()

print ("Percent of each component:")
for i in l:
    print (i.real/ cov_trace )

V_PCA = V[:,1:]
Xp = np.dot(dataset,V)
# Out:
# [[ 0.93590229  1.18243059  3.05459832]
#  [ 1.18243059 80.38592211 82.75806511]
#  [ 3.05459832 82.75806511 88.87936804]]
# [6.82423575e-04 2.64584411e+00 1.67554666e+02]
# [1.67764200e+02 2.64854346e+00 6.82425023e-04]
#
# Percent of each component:
# 4.009511128419336e-06
# 0.01554539115290253
# 0.9844505993359678

# %%
sf = 0.2 # scale factor
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12, 7))

# OLD COORDINATES
# (0,1) projection
axes[0, 0].scatter(dataset[:,0], dataset[:,1], marker='.', color='red', alpha=0.5, label="(0,1)")
axes[0, 0].plot([0, sf*l[0]*V[0,0]], [0, sf*l[0]*V[1,0]], color='blue', lw=2)
axes[0, 0].plot([0, sf*l[1]*V[0,1]], [0, sf*l[1]*V[1,1]], color='blue', lw=2)

# (0,2) projection
axes[0, 1].scatter(dataset[:,0], dataset[:,2], marker='.', color='red', alpha=0.5, label="(0,2)")
axes[0, 1].plot([0, sf*l[0]*V[0, 0]], [0, sf*l[0] * V[2, 0]], color='blue', lw=2)
axes[0, 1].plot([0, sf*l[2]*V[0, 2]], [0, sf*l[2] * V[2, 2]], color='blue', lw=2)

# (1,2) projection 
axes[0, 2].scatter(dataset[:,1], dataset[:,2], marker='.', color='red', alpha=0.5, label="(1,2)")
axes[0, 2].plot([0, sf*l[1]*V[1, 1]], [0, sf*l[1].real * V[2, 1]], color='blue', lw=2)
axes[0, 2].plot([0, sf*l[2]*V[1, 2]], [0, sf*l[2].real * V[2, 2]], color='blue', lw=2)


# NEW COORDINATES
# (0,1) projection
axes[1, 0].scatter(Xp[:,0], Xp[:,1], marker='.', color='red', alpha=0.5, label="(0,1)")
axes[1, 0].plot([0, sf*l[0]*V[0,0]], [0, sf*l[0]*V[1,0]], color='blue', lw=2)
axes[1, 0].plot([0, sf*l[1]*V[0,1]], [0, sf*l[1]*V[1,1]], color='blue', lw=2)

# (0,2) projection
axes[1, 1].scatter(Xp[:,0], Xp[:,2], marker='.', color='red', alpha=0.5, label="(0,2)")
axes[1, 1].plot([0, sf*l[0]*V[0, 0]], [0, sf*l[0] * V[2, 0]], color='blue', lw=2)
axes[1, 1].plot([0, sf*l[2]*V[0, 2]], [0, sf*l[2] * V[2, 2]], color='blue', lw=2)

# (1,2) projection 
axes[1, 2].scatter(Xp[:,1], Xp[:,2], marker='.', color='red', alpha=0.5, label="(1,2)")
axes[1, 2].plot([0, sf*l[1]*V[1, 1]], [0, sf*l[1].real * V[2, 1]], color='blue', lw=2)
axes[1, 2].plot([0, sf*l[2]*V[1, 2]], [0, sf*l[2].real * V[2, 2]], color='blue', lw=2)



axes[0, 1].set_title("Original coordinates", fontsize=14, loc='center')
axes[1, 1].set_title("New coordinates", fontsize=14, loc='center')

for row in axes:
    for ax in row:
        ax.legend()
        
plt.tight_layout()
plt.show()

# %% [markdown]
# 3 \. **Looking at an oscillating spring** (optional)
#
# Imagine you have $n$ cameras looking at a spring oscillating along the $x$ axis. Each  camera record the motion of the spring looking at it along a given direction defined by the pair $(\theta_i, \phi_i)$, the angles in spherical coordinates.
#
# Start from the simulation of the records (say ${\cal O}(1000)$) of the spring's motion along the x axis, assuming a little random noise affects the measurements along the $y$. Rotate such dataset to emulate the records of each camera.
#
# Perform a Principal Component Analysis on the thus obtained dataset, aiming at finding the only one coordinate that really matters.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Step 1: Simulate the spring's oscillation
n_points = 1000  # Number of time points
time = np.linspace(0, 10, n_points)
x_motion = np.sin(2 * np.pi * time)  # Sinusoidal oscillation along x
y_noise = np.random.normal(0, 0.05, size=n_points)  # Random noise along y

# Original dataset (spring motion)
original_data = np.column_stack((x_motion, y_noise))

# Step 2: Define camera perspectives
n_cameras = 5
angles = np.random.uniform(0, 2 * np.pi, size=(n_cameras, 2))  # Random (theta, phi)

# Transform data for each camera
camera_data = []
for theta, phi in angles:
    # Rotation matrix in 3D for spherical coordinates
    rotation_matrix = np.array([
        [np.cos(theta), -np.sin(theta) * np.cos(phi), np.sin(theta) * np.sin(phi)],
        [np.sin(theta), np.cos(theta) * np.cos(phi), -np.cos(theta) * np.sin(phi)],
        [0, np.sin(phi), np.cos(phi)],
    ])
    
    # Append rotated data (x_motion projected, y_noise random)
    rotated = rotation_matrix @ np.vstack((x_motion, y_noise, np.zeros(n_points)))
    camera_data.append(rotated[:2, :].T)  # Use first two dimensions

# Combine camera data into a single dataset
combined_data = np.vstack(camera_data)

# Step 3: Perform PCA
pca = PCA(n_components=2)  # We expect one dominant component
pca.fit(combined_data)

# Transformed dataset (principal components)
transformed_data = pca.transform(combined_data)

# Step 4: Plot results
plt.figure(figsize=(12, 6))

# Original spring motion
plt.subplot(1, 2, 1)
plt.plot(x_motion, y_noise, 'o', alpha=0.5, label="Original Data")
plt.xlabel('X (motion)')
plt.ylabel('Y (noise)')
plt.title('Original Spring Motion')
plt.legend()

# PCA components
plt.subplot(1, 2, 2)
plt.scatter(transformed_data[:, 0], transformed_data[:, 1], alpha=0.5, label="PCA Transformed Data")
plt.axhline(0, color='red', linestyle='--', label="Principal Axis")
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Combined Camera Data')
plt.legend()

plt.tight_layout()
plt.show()

# Display explained variance ratio
print("Explained Variance Ratios:", pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratios: [0.65710966 0.34289034]

# %% [markdown]
# 4\. **PCA on the MAGIC dataset** (optional)
#
# Perform a PCA on the magic04.data dataset

# %%
# get the dataset and its description on the proper data directory
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data -P ~/data/
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names -P ~/data/

# %%
file_name = "magic04.data"
df = pd.read_csv("magic04.data")

df_filtered = np.array(df.iloc[:,:10])
mean_variables = df_filtered.mean(axis=0)
sigma_variables = df_filtered.std(axis=0)

df_Z = (df_filtered - mean_variables) / sigma_variables 

cov_Z = np.cov(df_Z, rowvar=False)
k, A = la.eigh(cov_Z)
cov_Z_trace = cov_Z.trace()

print ("Percent of each component:")
for i in k:
    print (i / cov_Z_trace )

df_Z_PCA = np.dot(df_Z, A)
# Out:
# Percent of each component:
# 0.002024237546386506
# 0.01547541233978556
# 0.02203652279683742
# 0.04075462507136267
# 0.06500969545088238
# 0.07420321023163878
# 0.09939700538850582
# 0.10118037101066495
# 0.15751941145450216
# 0.4223995087094336
